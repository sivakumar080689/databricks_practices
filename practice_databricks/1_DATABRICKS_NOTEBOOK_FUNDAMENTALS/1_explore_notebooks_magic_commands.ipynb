# %%
# %lsmagic

# %%
"""

# %run "/Workspace/Users/sivakumar.bala89@gmail.com/databricks-code-repo/databricks_workouts_2025/1_DATABRICKS_NOTEBOOK_FUNDAMENTALS/4_child_notebook"

"""

# %%
# %sh
ls -l /databricks-datasets/airlines
head -l /databricks-datasets/airlines/part-01902

# %%
# %sql

CREATE VOLUME IF NOT EXISTS workspace.default.volumewd36_datalake;

# %%
# %fs ls "dbfs:///Volumes/workspace/default/volumewd36_datalake"

# %%
# %fs cp "dbfs:///Volumes/workspace/default/volumewd36_datalake/patients.csv" "dbfs:///Volumes/workspace/default/volumewd36_datalake/patients_copy.csv"

# %%
# %sql 
create table if not exists default.cities2(id int,city string);
insert into default.cities2 values(3,'Mumbai'),(4,'Lucknow');
select * from cities2;

# %%
# %python

spark.sql("select * from cities2").explain(True)

# %%
# %sql

update cities2 set city='kolkata' where id=4;

# %%
# %sql
show create table cities2;

# %%
# %sql

from cities2 select * ;

# %%
def sqrt(a):
    return a*a

# %%
print("square root function call", sqrt(10))

# %%
# %pip install pypi
